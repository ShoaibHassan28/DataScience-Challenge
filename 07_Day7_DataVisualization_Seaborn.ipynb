# %% [markdown]
# # ✅ Day 7: Data Visualization with Seaborn

# %% [markdown]
# ## 📌 What is Seaborn
# Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # 📌 Load Sample Dataset

# %%
df = sns.load_dataset('tips')  # Built-in dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 📌 Scatter Plot

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex')
plt.title("Scatter Plot: Total Bill vs Tip")
plt.show()

# %% [markdown]
# # 📌 Line Plot

# %%
sns.lineplot(data=df, x='size', y='total_bill')
plt.title("Line Plot: Size vs Total Bill")
plt.show()

# %% [markdown]
# # 📌 Bar Plot

# %%
sns.barplot(data=df, x='day', y='total_bill', hue='sex')
plt.title("Bar Plot: Total Bill per Day by Gender")
plt.show()

# %% [markdown]
# # 📌 Histogram

# %%
sns.histplot(data=df, x='total_bill', kde=True)
plt.title("Histogram: Total Bill Distribution")
plt.show()

# %% [markdown]
# # 🎯 Mini Task
# Create a scatter plot of total_bill vs tip with hue based on time.
#
# Create a histogram for the size column.

# %%
# Load the tips dataset
df = sns.load_dataset('tips')

# Scatter plot
sns.scatterplot(data=df, x='total_bill', y='tip', hue='time')
plt.title("Scatter Plot: Total Bill vs Tip (Hue = Time)")
plt.show()

sns.histplot(data=df, x='size', bins=6, kde=False)
plt.title("Histogram: Size Distribution")
plt.xlabel("Size of the Group")
plt.ylabel("Frequency")
plt.show()
